# %% [markdown]
# #### PythonでExcel業務を自動化
#
# 1.学習で使用するExcelシートは最大12行であることを前提として学習を進める。
# 2.学習で使用するExcelブックは3つとも同じフォーマットであることを前提に学習を進める。

# %%
# !pip install xlrd openpyxl

# %%
#　必要なライブラリをインポートする 
import pandas as pd
from glob import glob

# %%
# Excelファイルのパスを取得する
filepaths = glob('resources/*.xlsx')
filepaths
# Out:
# ['resources/請求書_10月_PGI_Inc.xlsx',
#  'resources/請求書_11月_PGI_Inc.xlsx',
#  'resources/請求書_12月_PGI_Inc.xlsx']

# %%
filepath = filepaths[0]
filepath
# Out:
# 'resources/請求書_10月_PGI_Inc.xlsx'

# %% [markdown]
# #### 最初に処理対象のExcelから必要な情報だけを取り出す

# %%
_df = pd.read_excel(filepath)
# _df

# %%
columns = _df.iloc[10, [1,2,4,10,11,14]]
columns
# Out:
# Unnamed: 1                 日付
# Unnamed: 2              商品コード
# Unnamed: 4                 品名
# Unnamed: 10      数量[L] or [-]
# Unnamed: 11    単価[¥/L] or [¥]
# Unnamed: 14                金額
# Name: 10, dtype: object

# %%
# Excelから必要な項目だけを抽出する
df = _df.iloc[11:23, [1, 2, 4, 10, 11, 14]]

#項目名をセットして、さらにExcelから必要な項目だけを抽出する
df.columns = columns
df
# Out:
# 10                   日付    商品コード     品名 数量[L] or [-] 単価[¥/L] or [¥]    金額
# 11  2020-10-04 00:00:00  GSL0001  レギュラー           20            120  2400
# 12  2020-10-05 00:00:00  GSL0002   ハイオク           45            160  7200
# 13  2020-10-06 00:00:00  GSL0003     軽油           50            100  5000
# 14  2020-10-07 00:00:00  GDS0002    コロン            3            800  2400
# 15  2020-10-08 00:00:00  CMT0004  オイル交換            1           1000  1000
# 16  2020-10-09 00:00:00  CMT0002   洗車 B            1           1500  1500
# 17  2020-10-10 00:00:00  GSL0003     軽油           50            100  5000
# 18  2020-10-11 00:00:00  GSL0002   ハイオク           40            160  6400
# 19  2020-10-12 00:00:00  CMT0005  タイヤ交換            1           4000  4000
# 20  2020-10-13 00:00:00  GSL0003     軽油           50            100  5000
# 21  2020-10-14 00:00:00  GSL0003     軽油           50            100  5000
# 22                  NaN      NaN    NaN          NaN            NaN     0

# %%
df['企業名'] = _df.iloc[2,0]
df.head()
# Out:
# 10                   日付    商品コード     品名 数量[L] or [-] 単価[¥/L] or [¥]    金額  \
# 11  2020-10-04 00:00:00  GSL0001  レギュラー           20            120  2400
# 12  2020-10-05 00:00:00  GSL0002   ハイオク           45            160  7200
# 13  2020-10-06 00:00:00  GSL0003     軽油           50            100  5000
# 14  2020-10-07 00:00:00  GDS0002    コロン            3            800  2400
# 15  2020-10-08 00:00:00  CMT0004  オイル交換            1           1000  1000
#
# 10              企業名
# 11  Primagest, Inc.
# 12  Primagest, Inc.
# 13  Primagest, Inc.
# 14  Primagest, Inc.
# 15  Primagest, Inc.

# %%
df['企業コード'] = _df.iloc[3, 4]
df['請求書No'] = _df.iloc[2, 12]
df['発行日'] = _df.iloc[3, 12]
df['発行者'] = _df.iloc[4, 12]
df['発行者コード'] = _df.iloc[4, 13]
df.head()
# Out:
# 10                   日付    商品コード     品名 数量[L] or [-] 単価[¥/L] or [¥]    金額  \
# 11  2020-10-04 00:00:00  GSL0001  レギュラー           20            120  2400
# 12  2020-10-05 00:00:00  GSL0002   ハイオク           45            160  7200
# 13  2020-10-06 00:00:00  GSL0003     軽油           50            100  5000
# 14  2020-10-07 00:00:00  GDS0002    コロン            3            800  2400
# 15  2020-10-08 00:00:00  CMT0004  オイル交換            1           1000  1000
#
# 10              企業名  企業コード 請求書No         発行日 発行者  発行者コード
# 11  Primagest, Inc.      6   012  2020/10/31  綿貫     2.0
# 12  Primagest, Inc.      6   012  2020/10/31  綿貫     2.0
# 13  Primagest, Inc.      6   012  2020/10/31  綿貫     2.0
# 14  Primagest, Inc.      6   012  2020/10/31  綿貫     2.0
# 15  Primagest, Inc.      6   012  2020/10/31  綿貫     2.0

# %%
# 一連の処理を関数化する

def extract(filepath):
    _df = pd.read_excel(filepath)
    columns = _df.iloc[10, [1,2,4,10,11,14]]
    df = _df.iloc[11:23, [1, 2, 4, 10, 11, 14]]
    df.columns = columns
    df['企業名'] = _df.iloc[2,0]
    df['企業コード'] = _df.iloc[3, 4]
    df['請求書No'] = _df.iloc[2, 12]
    df['発行日'] = _df.iloc[3, 12]
    df['発行者'] = _df.iloc[4, 12]
    df['発行者コード'] = _df.iloc[4, 13]
    return df

# %%
df = extract(filepath)
df.head()
# Out:
# 10                   日付    商品コード     品名 数量[L] or [-] 単価[¥/L] or [¥]    金額  \
# 11  2020-10-04 00:00:00  GSL0001  レギュラー           20            120  2400
# 12  2020-10-05 00:00:00  GSL0002   ハイオク           45            160  7200
# 13  2020-10-06 00:00:00  GSL0003     軽油           50            100  5000
# 14  2020-10-07 00:00:00  GDS0002    コロン            3            800  2400
# 15  2020-10-08 00:00:00  CMT0004  オイル交換            1           1000  1000
#
# 10              企業名  企業コード 請求書No         発行日 発行者  発行者コード
# 11  Primagest, Inc.      6   012  2020/10/31  綿貫     2.0
# 12  Primagest, Inc.      6   012  2020/10/31  綿貫     2.0
# 13  Primagest, Inc.      6   012  2020/10/31  綿貫     2.0
# 14  Primagest, Inc.      6   012  2020/10/31  綿貫     2.0
# 15  Primagest, Inc.      6   012  2020/10/31  綿貫     2.0

# %%
# ３つのExcelブックを結合することにトライする。
# まずは[pd.concat]メソッドを使用する方法について学習する。

# %%
# test Data Frameを用意する
sample_1 = pd.DataFrame([[1,2,3],[4,5,6]])
sample_2 = pd.DataFrame([[-1,0,3],[9,7,6]])

# %%
# 上記二つのデータフレームを(縦方向)に結合してみる。
pd.concat([sample_1, sample_2])
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 0 -1  0  3
# 1  9  7  6

# %%
# 上記二つのデータフレームを(横方向)に結合してみる。
pd.concat([sample_1, sample_2], axis=1)
# Out:
#    0  1  2  0  1  2
# 0  1  2  3 -1  0  3
# 1  4  5  6  9  7  6

# %%
# では処理対象のExcelを結合（集計）を試してみる。

#　空のデータフレームを用意する
df = pd.DataFrame()

# 処理対象の３つのExcelブックのパスを取り出す
for filepath in filepaths:
    _df= extract(filepath)
    df = pd.concat([df, _df])

# %%
df
# Out:
# 10                   日付    商品コード     品名 数量[L] or [-] 単価[¥/L] or [¥]    金額  \
# 11  2020-10-04 00:00:00  GSL0001  レギュラー           20            120  2400
# 12  2020-10-05 00:00:00  GSL0002   ハイオク           45            160  7200
# 13  2020-10-06 00:00:00  GSL0003     軽油           50            100  5000
# 14  2020-10-07 00:00:00  GDS0002    コロン            3            800  2400
# 15  2020-10-08 00:00:00  CMT0004  オイル交換            1           1000  1000
# 16  2020-10-09 00:00:00  CMT0002   洗車 B            1           1500  1500
# 17  2020-10-10 00:00:00  GSL0003     軽油           50            100  5000
# 18  2020-10-11 00:00:00  GSL0002   ハイオク           40            160  6400
# 19  2020-10-12 00:00:00  CMT0005  タイヤ交換            1           4000  4000
# 20  2020-10-13 00:00:00  GSL0003     軽油           50            100  5000
# 21  2020-10-14 00:00:00  GSL0003     軽油           50            100  5000
# 22                  NaN      NaN    NaN          NaN            NaN     0
# 11  2020-11-01 00:00:00  GSL0001  レギュラー           20            120  2400
# 12  2020-11-02 00:00:00  GSL0002   ハイオク           45            160  7200
# 13  2020-11-05 00:00:00  GSL0003     軽油           50            100  5000
# 14  2020-11-10 00:00:00  GSL0004     灯油           30             80  2400
# 15  2020-11-11 00:00:00  GSL0001  レギュラー           30            120  3600
# 16  2020-11-12 00:00:00  GSL0002   ハイオク           30            160  4800
# 17  2020-11-13 00:00:00  CMT0003   洗車 C            1           3000  3000
# 18  2020-11-20 00:00:00  GSL0004     灯油           15             80  1200
# 19  2020-11-23 00:00:00  CMT0003   洗車 C            1           3000  3000
# 20  2020-11-25 00:00:00  GSL0004     灯油           40             80  3200
# 21                  NaN      NaN    NaN          NaN            NaN     0
# 22                  NaN      NaN    NaN          NaN            NaN     0
# 11  2020-12-01 00:00:00  GSL0001  レギュラー           35            120  4200
# 12  2020-12-06 00:00:00  GSL0001  レギュラー           15            120  1800
# 13  2020-12-06 00:00:00  GSL0003     軽油           50            100  5000
# 14  2020-12-08 00:00:00  GSL0001  レギュラー           40            120  4800
# 15  2020-12-09 00:00:00  GSL0003     軽油           50            100  5000
# 16  2020-12-11 00:00:00  GSL0001  レギュラー           30            120  3600
# 17  2020-12-17 00:00:00  GSL0003     軽油           50            100  5000
# 18  2020-12-20 00:00:00  GSL0002   ハイオク           20            160  3200
# 19  2020-12-27 00:00:00  GSL0002   ハイオク           15            160  2400
# 20  2020-12-27 00:00:00  GSL0003     軽油           60            100  6000
# 21  2020-12-30 00:00:00  GSL0003     軽油           35            100  3500
# 22                  NaN      NaN    NaN          NaN            NaN     0
#
# 10              企業名  企業コード 請求書No         発行日 発行者  発行者コード
# 18  Primagest, Inc.      4   008  2020/11/30  山岡     8.0  2020-11-20 00:00:00
# 19  Primagest, Inc.      4   008  2020/11/30  山岡     8.0  2020-11-23 00:00:00
# 20  Primagest, Inc.      4   008  2020/11/30  山岡     8.0  2020-11-25 00:00:00
# 11  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-01 00:00:00
# 12  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-06 00:00:00
# 13  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-06 00:00:00
# 14  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-08 00:00:00
# 15  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-09 00:00:00
# 16  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-11 00:00:00
# 17  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-17 00:00:00
# 18  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-20 00:00:00
# 19  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-27 00:00:00
# 20  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-27 00:00:00
# 21  Primagest, Inc.      6   012  2020/12/30  岸辺     2.0  2020-12-30 00:00:00
#
# 10    商品コード     品名 数量[L] or [-] 単価[¥/L] or [¥]    金額
# 11  GSL0001  レギュラー           20            120  2400
# 12  GSL0002   ハイオク           45            160  7200
# 13  GSL0003     軽油           50            100  5000
# 14  GDS0002    コロン            3            800  2400
# 15  CMT0004  オイル交換            1           1000  1000
# 16  CMT0002   洗車 B            1           1500  1500
# 17  GSL0003     軽油           50            100  5000
# 18  GSL0002   ハイオク           40            160  6400
# 19  CMT0005  タイヤ交換            1           4000  4000
# 20  GSL0003     軽油           50            100  5000
# 21  GSL0003     軽油           50            100  5000
# 11  GSL0001  レギュラー           20            120  2400
# 12  GSL0002   ハイオク           45            160  7200
# 13  GSL0003     軽油           50            100  5000
# 14  GSL0004     灯油           30             80  2400
# 15  GSL0001  レギュラー           30            120  3600
# 16  GSL0002   ハイオク           30            160  4800
# 17  CMT0003   洗車 C            1           3000  3000
# 18  GSL0004     灯油           15             80  1200
# 19  CMT0003   洗車 C            1           3000  3000
# 20  GSL0004     灯油           40             80  3200
# 11  GSL0001  レギュラー           35            120  4200
# 12  GSL0001  レギュラー           15            120  1800
# 13  GSL0003     軽油           50            100  5000
# 14  GSL0001  レギュラー           40            120  4800
# 15  GSL0003     軽油           50            100  5000
# 16  GSL0001  レギュラー           30            120  3600
# 17  GSL0003     軽油           50            100  5000
# 18  GSL0002   ハイオク           20            160  3200
# 19  GSL0002   ハイオク           15            160  2400
# 20  GSL0003     軽油           60            100  6000
# 21  GSL0003     軽油           35            100  3500

# %%
# 最後に上記の結合(集計)したデータフレームを一つのExcelブックにまとめて出力する。
df.to_excel('output/all_data.xlsx', index=False)
